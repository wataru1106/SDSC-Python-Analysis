# %%
# #Bリーグ全体、ロジスティック回帰を実施
# df = df_box_gameid_sum.copy()

# #説明変数の設定
# exp_val = ['ブロックショット','ファウル','ダンク','被ブロックショット','ディフェンスリバウンド','スティール','ターンオーバ','ファストブレイクポイント','アシスト','セカンドチャンスポイント','3P成功','オフェンスリバウンド','被ファウル','3P試投','2P試投','フリースロー成功','2Pインサイドポイント','2P成功','フリースロー試投']
# x = df[exp_val]
# x2 = sm.add_constant(x) #切片を計算するために説明変数のデータの中に全て1からなる列を追加

# #目的変数の設定
# obj_val = ["勝敗"]
# y = df[obj_val]

# #ロジスティック回帰モデルを作る
# model = sm.Logit(y,x2)
# result = model.fit()

# #サマリを表示する
# result.summary()



# #越谷アルファーズ、ロジスティック回帰を実施
# df_alphas = df_box_gameid_sum[df_box_gameid_sum['チームID'] == 745].copy()

# #説明変数の設定
# exp_val = ['ブロックショット','ファウル','ダンク','被ブロックショット','ディフェンスリバウンド','スティール','ターンオーバ','ファストブレイクポイント','アシスト','セカンドチャンスポイント','3P成功','オフェンスリバウンド','被ファウル','3P試投','2P試投','フリースロー成功','2Pインサイドポイント','2P成功','フリースロー試投']
# x = df_alphas[exp_val]
# x2 = sm.add_constant(x) #切片を計算するために説明変数のデータの中に全て1からなる列を追加

# #目的変数の設定
# obj_val = ["勝敗"]
# y = df_alphas[obj_val]

# #ロジスティック回帰モデルを作る
# model = sm.Logit(y,x2)
# result = model.fit()

# #サマリを表示する
# result.summary()



# #Bリーグ全体、L1ロジスティック回帰を実施
# # ===== データ準備 =====
# df = df_box_gameid_sum.copy()

# # 説明変数
# exp_val = [
#     'ブロックショット','ファウル','ダンク','被ブロックショット',
#     'ディフェンスリバウンド','スティール','ターンオーバ','ファストブレイクポイント',
#     'アシスト','セカンドチャンスポイント','3P成功','オフェンスリバウンド',
#     '被ファウル','3P試投','2P試投','フリースロー成功',
#     '2Pインサイドポイント','2P成功','フリースロー試投'
# ]

# # 目的変数
# x = df[exp_val]
# x = sm.add_constant(x)  # 切片を追加
# y = df["勝敗"]

# # ===== L1正則化付きロジスティック回帰 =====
# # alpha: 正則化の強さ（大きいほど強い制約 → 係数がより0に近づく）
# model = sm.Logit(y, x)
# result = model.fit_regularized(
#     method='l1',   # L1正則化を指定
#     alpha=1,     # 正則化の強さ（0.01〜1.0あたりで調整）
#     maxiter=1000
# )

# # ===== 結果表示 =====
# result.summary()



# #Bリーグ全体、L1ロジスティック回帰を実施
# # ===== データ準備 =====
# df = df_box_gameid_sum.copy()

# # 説明変数
# exp_val = [
#     'ブロックショット','ファウル','ダンク','被ブロックショット',
#     'ディフェンスリバウンド','スティール','ターンオーバ','ファストブレイクポイント',
#     'アシスト','セカンドチャンスポイント','3P成功','オフェンスリバウンド',
#     '被ファウル','3P試投','2P試投','フリースロー成功',
#     '2Pインサイドポイント'
# ]

# # 目的変数
# x = df[exp_val]
# x = sm.add_constant(x)  # 切片を追加
# y = df["勝敗"]

# # ===== L1正則化付きロジスティック回帰 =====
# # alpha: 正則化の強さ（大きいほど強い制約 → 係数がより0に近づく）
# model = sm.Logit(y, x)
# result = model.fit_regularized(
#     method='l1',   # L1正則化を指定
#     alpha=1,     # 正則化の強さ（0.01〜1.0あたりで調整）
#     maxiter=1000
# )

# # ===== 結果表示 =====
# result.summary()




# #越谷アルファーズ、L1ロジスティック回帰を実施
# # ===== データ準備 =====
# df_alphas = df_box_gameid_sum[df_box_gameid_sum['チームID'] == 745].copy()

# # 説明変数
# exp_val = [
#     'ブロックショット','ファウル','ダンク','被ブロックショット',
#     'ディフェンスリバウンド','スティール','ターンオーバ','ファストブレイクポイント',
#     'アシスト','セカンドチャンスポイント','3P成功','オフェンスリバウンド',
#     '被ファウル','3P試投','2P試投','フリースロー成功',
#     '2Pインサイドポイント','2P成功','フリースロー試投'
# ]

# # 目的変数
# x = df_alphas[exp_val]
# x = sm.add_constant(x)  # 切片を追加
# y = df_alphas["勝敗"]

# # ===== L1正則化付きロジスティック回帰 =====
# # alpha: 正則化の強さ（大きいほど強い制約 → 係数がより0に近づく）
# model = sm.Logit(y, x)
# result = model.fit_regularized(
#     method='l1',   # L1正則化を指定
#     alpha=1,     # 正則化の強さ（0.01〜1.0あたりで調整）
#     maxiter=1000
# )

# # ===== 結果表示 =====
# result.summary()





# #越谷アルファーズ、L1ロジスティック回帰を実施
# # ===== データ準備 =====
# df_alphas = df_box_gameid_sum[df_box_gameid_sum['チームID'] == 745].copy()

# # 説明変数
# exp_val = [
#     'ブロックショット','ファウル','ダンク','被ブロックショット',
#     'ディフェンスリバウンド','スティール','ターンオーバ','ファストブレイクポイント',
#     'アシスト','セカンドチャンスポイント','3P成功','オフェンスリバウンド',
#     '被ファウル','3P試投','2P試投','フリースロー成功',
#     '2Pインサイドポイント'
# ]

# # 目的変数
# x = df_alphas[exp_val]
# x = sm.add_constant(x)  # 切片を追加
# y = df_alphas["勝敗"]

# # ===== L1正則化付きロジスティック回帰 =====
# # alpha: 正則化の強さ（大きいほど強い制約 → 係数がより0に近づく）
# model = sm.Logit(y, x)
# result = model.fit_regularized(
#     method='l1',   # L1正則化を指定
#     alpha=1,     # 正則化の強さ（0.01〜1.0あたりで調整）
#     maxiter=1000
# )

# # ===== 結果表示 =====
# result.summary()




# #目的変数を'得点'としたVIFを計算
# df = df_box_gameid_sum.copy()

# y = df["勝敗"]
# x = df.drop(['ピリオド区分', 'チームID', '試合ID',"勝敗", '得点', 'トータルリバウンド'], axis=1)

# x.corr()

# vif = np.diag(np.linalg.inv(x.corr().values))
# df_vif = pd.DataFrame(vif)
# df_vif.columns = ["VIF"]
# df_vif.index = x.corr().columns
# df_vif.sort_values("VIF")
